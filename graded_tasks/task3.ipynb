# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# # Rectify the frame

# %%
# Apply Homographic transformation to frame
image = cv2.imread('../data/images/frame.jpg')
plt.imshow(image)

# %% [markdown]
# # Stitch the following two images together

# %%
image1 = cv2.imread('../data/images/keble.000.png')
image2 = cv2.imread('../data/images/keble.003.png')
plt.imshow(image1)
plt.show()
plt.imshow(image2)
